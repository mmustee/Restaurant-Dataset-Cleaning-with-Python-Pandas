# %%
import pandas as pd

# %%
data = pd.read_csv("zomato.csv")

# %%
data.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='str')

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  str
#  1   address                      51717 non-null  str
#  2   name                         51717 non-null  str
#  3   online_order                 51717 non-null  str
#  4   book_table                   51717 non-null  str
#  5   rate                         43942 non-null  str
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  str
#  8   location                     51696 non-null  str
#  9   rest_type                    51490 non-null  str
#  10  dish_liked                   23639 non-null  str
#  11  cuisines                     51672 non-null  str
#  12  approx_cost(for two people)  51371 non-null  str
# ...

# %%
data.shape
# Out:
# (51717, 17)

# %%
"""Deleting redundant columns.
Renaming the columns.
Dropping duplicates.
Cleaning individual columns.
Remove the NaN values from the dataset
Check for some more Transformations"""
# Out:
# 'Deleting redundant columns.\nRenaming the columns.\nDropping duplicates.\nCleaning individual columns.\nRemove the NaN values from the dataset\nCheck for some more Transformations'

# %%
data.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='str')

# %%
columns_to_keep = ['name', 'online_order', 'book_table', 'rate','dish_liked','approx_cost(for two people)']
columns_to_drop = ['url', 'address','phone', 'location', 'rest_type', 'cuisines','reviews_list', 'menu_item',
       'listed_in(type)', 'listed_in(city)' ]

# %%
data[columns_to_keep]
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate                                         dish_liked  \
# ...

# %%
modify_data = data[columns_to_keep]

# %%
modify_data
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate                                         dish_liked  \
# ...

# %% [markdown]
# # 2nd Way - Dropping columns

# %%
data.drop(columns= columns_to_drop, inplace= True)

# %%
data
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate  votes  \
# 0            Yes   4.1/5    775
# 1             No   4.1/5    787
# ...

# %% [markdown]
# # Renaming Columns

# %% [markdown]
# ### renaming columns 1 by 1

# %%
data.rename(columns= {"name":"name1"})
# Out:
#                                                    name1 online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate  votes  \
# 0            Yes   4.1/5    775
# 1             No   4.1/5    787
# ...

# %%
data.columns
# Out:
# Index(['name', 'online_order', 'book_table', 'rate', 'votes', 'dish_liked',
#        'approx_cost(for two people)'],
#       dtype='str')

# %%
data.columns[0].capitalize()
# Out:
# 'Name'

# %%
for i in data.columns:
    print(i.capitalize())
# Out:
# Name
# Online_order
# Book_table
# Rate
# Votes
# Dish_liked
# Approx_cost(for two people)

# %%
new_column_names =  []
for i in data.columns:
    new_column_names.append(i.capitalize())

# %%
data.columns = new_column_names

# %%
data.head()
# Out:
#                     Name Online_order Book_table   Rate  Votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#                                           Dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
#
#   Approx_cost(for two people)
# 0                         800
# 1                         800
# 2                         800
# 3                         300
# 4                         600

# %% [markdown]
# # Dropping Duplicates

# %%
data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51712     True
# 51713     True
# 51714    False
# 51715     True
# 51716     True
# Length: 51717, dtype: bool

# %%
data.duplicated().sum()
# Out:
# np.int64(29103)

# %%
data.duplicated().value_counts()
# Out:
# True     29103
# False    22614
# Name: count, dtype: int64

# %%
data.drop_duplicates(inplace = True)

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Removing the NaN values

# %%
data.isna().sum()
# Out:
# Name                               0
# Online_order                       0
# Book_table                         0
# Rate                            2420
# Votes                              0
# Dish_liked                     11348
# Approx_cost(for two people)      141
# dtype: int64

# %%
data.dropna(inplace= True)

# %%
data.isna().sum()
# Out:
# Name                           0
# Online_order                   0
# Book_table                     0
# Rate                           0
# Votes                          0
# Dish_liked                     0
# Approx_cost(for two people)    0
# dtype: int64

# %%
data
# Out:
#                                               Name Online_order Book_table  \
# 0                                            Jalsa          Yes        Yes
# 1                                   Spice Elephant          Yes         No
# 2                                  San Churro Cafe          Yes         No
# 3                            Addhuri Udupi Bhojana           No         No
# 4                                    Grand Village           No         No
# ...                                            ...          ...        ...
# 51615                                Little Onnion          Yes         No
# 51617                              Breakfast House           No         No
# 51620                               Fujian Express          Yes         No
# 51628  Nook - Aloft Bengaluru Cessna Business Park           No        Yes
# 51677                                      Bhagini           No         No
#
# ...

# %%
data.reset_index(inplace = True)

# %%
data
# Out:
#        index                                         Name Online_order  \
# 0          0                                        Jalsa          Yes
# 1          1                               Spice Elephant          Yes
# 2          2                              San Churro Cafe          Yes
# 3          3                        Addhuri Udupi Bhojana           No
# 4          4                                Grand Village           No
# ...      ...                                          ...          ...
# 11188  51615                                Little Onnion          Yes
# 11189  51617                              Breakfast House           No
# 11190  51620                               Fujian Express          Yes
# 11191  51628  Nook - Aloft Bengaluru Cessna Business Park           No
# 11192  51677                                      Bhagini           No
#
#       Book_table    Rate  Votes  \
# 0            Yes   4.1/5    775
# 1             No   4.1/5    787
# ...

# %%
data.drop(columns = "index", inplace= True)

# %%
data
# Out:
#                                               Name Online_order Book_table  \
# 0                                            Jalsa          Yes        Yes
# 1                                   Spice Elephant          Yes         No
# 2                                  San Churro Cafe          Yes         No
# 3                            Addhuri Udupi Bhojana           No         No
# 4                                    Grand Village           No         No
# ...                                            ...          ...        ...
# 11188                                Little Onnion          Yes         No
# 11189                              Breakfast House           No         No
# 11190                               Fujian Express          Yes         No
# 11191  Nook - Aloft Bengaluru Cessna Business Park           No        Yes
# 11192                                      Bhagini           No         No
#
# ...

# %% [markdown]
# # Cleaning Individual Columns

# %%
data["Rate"]
# Out:
# 0         4.1/5
# 1         4.1/5
# 2         3.8/5
# 3         3.7/5
# 4         3.8/5
#           ...
# 11188    3.8 /5
# 11189    3.6 /5
# 11190    3.8 /5
# 11191    4.2 /5
# 11192    2.5 /5
# Name: Rate, Length: 11193, dtype: str

# %%
data["Rate"][10]
# Out:
# '4.2/5'

# %%
type(data["Rate"][10])
# Out:
# str

# %%
data["Rate"]= data["Rate"].str.replace(" ", "")

# %%
data["Rate"] = data["Rate"].str.replace("/", " out of ")

# %%
data
# Out:
#                                               Name Online_order Book_table  \
# 0                                            Jalsa          Yes        Yes
# 1                                   Spice Elephant          Yes         No
# 2                                  San Churro Cafe          Yes         No
# 3                            Addhuri Udupi Bhojana           No         No
# 4                                    Grand Village           No         No
# ...                                            ...          ...        ...
# 11188                                Little Onnion          Yes         No
# 11189                              Breakfast House           No         No
# 11190                               Fujian Express          Yes         No
# 11191  Nook - Aloft Bengaluru Cessna Business Park           No        Yes
# 11192                                      Bhagini           No         No
#
# ...

# %%
data["Online_order"]
# Out:
# 0        Yes
# 1        Yes
# 2        Yes
# 3         No
# 4         No
#         ...
# 11188    Yes
# 11189     No
# 11190    Yes
# 11191     No
# 11192     No
# Name: Online_order, Length: 11193, dtype: str

# %%
data["Online_order"] = data["Online_order"].map({"Yes": 1, "No": 0})

# %%
data
# Out:
#                                               Name  Online_order Book_table  \
# 0                                            Jalsa             1        Yes
# 1                                   Spice Elephant             1         No
# 2                                  San Churro Cafe             1         No
# 3                            Addhuri Udupi Bhojana             0         No
# 4                                    Grand Village             0         No
# ...                                            ...           ...        ...
# 11188                                Little Onnion             1         No
# 11189                              Breakfast House             0         No
# 11190                               Fujian Express             1         No
# 11191  Nook - Aloft Bengaluru Cessna Business Park             0        Yes
# 11192                                      Bhagini             0         No
#
# ...

# %%
data["Online_order"].value_counts()
# Out:
# Online_order
# 1    7822
# 0    3371
# Name: count, dtype: int64

# %% [markdown]
# # Export to CSV

# %%
data.to_csv("Cleaned_data.csv")

# %%
pd.read_csv("Cleaned_data.csv")
# Out:
#        Unnamed: 0                                         Name  Online_order  \
# 0               0                                        Jalsa             1
# 1               1                               Spice Elephant             1
# 2               2                              San Churro Cafe             1
# 3               3                        Addhuri Udupi Bhojana             0
# 4               4                                Grand Village             0
# ...           ...                                          ...           ...
# 11188       11188                                Little Onnion             1
# 11189       11189                              Breakfast House             0
# 11190       11190                               Fujian Express             1
# 11191       11191  Nook - Aloft Bengaluru Cessna Business Park             0
# 11192       11192                                      Bhagini             0
#
#       Book_table          Rate  Votes  \
# ...

# %%
data.to_csv("Cleaned_data_without_index.csv", index = False )

# %%
pd.read_csv("Cleaned_data_without_index.csv")
# Out:
#                                               Name  Online_order Book_table  \
# 0                                            Jalsa             1        Yes
# 1                                   Spice Elephant             1         No
# 2                                  San Churro Cafe             1         No
# 3                            Addhuri Udupi Bhojana             0         No
# 4                                    Grand Village             0         No
# ...                                            ...           ...        ...
# 11188                                Little Onnion             1         No
# 11189                              Breakfast House             0         No
# 11190                               Fujian Express             1         No
# 11191  Nook - Aloft Bengaluru Cessna Business Park             0        Yes
# 11192                                      Bhagini             0         No
#
# ...
